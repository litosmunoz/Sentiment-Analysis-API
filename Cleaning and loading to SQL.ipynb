# %% [markdown]
# ### Data Wrangling

# %%
import pandas as pd

# %%
df = pd.read_csv ('./data/cleandata.csv', encoding='unicode_escape')
df
# Out:
#                                                  Tweets  Retweets    Likes  \
# 0                              @PeterSchiff ð¤£ thanks       209     7021
# 1                                 @ZubyMusic Absolutely       755    26737
# 2      Dear Twitter Advertisers https://t.co/GMwHmInPAS     55927   356623
# 3        Meeting a lot of cool people at Twitter today!      9366   195546
# 4     Entering Twitter HQ â let that sink in! http...    145520  1043592
# ...                                                 ...       ...      ...
# 2663  @LimitingThe @baglino Just that manganese is a...       171     3173
# 2664              @incentives101 @ICRicardoLara Exactly       145     4234
# 2665  @ICRicardoLara Your policies are directly resp...       421     6144
# 2666   @ICRicardoLara You should be voted out of office       484     7029
# 2667         CB radios are free from govt/media control     11302   113429
#
#                      Date                                     Cleaned_Tweets
# 0     2022-10-27 16:17:39                                             thanks
# 1     2022-10-27 13:19:25                                         Absolutely
# 2     2022-10-27 13:08:00                           Dear Twitter Advertisers
# 3     2022-10-26 21:39:32     Meeting a lot of cool people at Twitter today!
# 4     2022-10-26 18:45:58          Entering Twitter HQ â let that sink in!
# ...                   ...                                                ...
# 2663  2022-01-27 22:01:06  Just that manganese is an alternative to iron ...
# 2664  2022-01-27 21:23:20                                            Exactly
# 2665  2022-01-27 21:13:57  Your policies are directly responsible for the...
# 2666  2022-01-27 21:12:27                  You should be voted out of office
# 2667  2022-01-27 21:00:09         CB radios are free from govt/media control
#
# [2668 rows x 5 columns]

# %%
df['Date'] = df['Date'].str.extract('(\d{4}-\d{2}-\d{2})', expand=True)
df['Date'] = pd.to_datetime(df["Date"])
df.sort_values(by='Date', inplace=True)
df = df.set_index('Date')

# %%
df
# Out:
#                                                        Tweets  Retweets  \
# Date
# 2022-01-27         CB radios are free from govt/media control     11302
# 2022-01-27  And in the darkness bind them https://t.co/Bvx...     33028
# 2022-01-27  @guper777 Honestly, I would let the border reg...       281
# 2022-01-27                          @cybrtrkguy Vote them out      7712
# 2022-01-27  If you scare people enough, they will demand r...    119804
# ...                                                       ...       ...
# 2022-10-26                                @eldsjal Concerning       719
# 2022-10-26  âAccording to unnamed sources close to the m...      4603
# 2022-10-27   Dear Twitter Advertisers https://t.co/GMwHmInPAS     55927
# 2022-10-27                              @ZubyMusic Absolutely       755
# 2022-10-27                           @PeterSchiff ð¤£ thanks       209
#
#              Likes                                     Cleaned_Tweets
# Date
# 2022-01-27  113429         CB radios are free from govt/media control
# 2022-01-27  195919                      And in the darkness bind them
# 2022-01-27    4627  Honestly, I would let the border regions vote....
# 2022-01-27   68748                                      Vote them out
# 2022-01-27  543466  If you scare people enough, they will demand r...
# ...            ...                                                ...
# 2022-10-26   17443                                         Concerning
# 2022-10-26   62693  âAccording to unnamed sources close to the m...
# 2022-10-27  356623                           Dear Twitter Advertisers
# 2022-10-27   26737                                         Absolutely
# 2022-10-27    7021                                             thanks
#
# [2668 rows x 4 columns]

# %%
df["day"] = pd.DatetimeIndex(df.index).day
df["month"] = pd.DatetimeIndex(df.index).month
df["year"] = pd.DatetimeIndex(df.index).year
df = df.drop(['Tweets'], axis =1)

# %%
new_order= ['day', 'month', 'year', 'Cleaned_Tweets', 'Retweets', 'Likes']
df = df[new_order]
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    day  month  year                                     Cleaned_Tweets  \
# 0   27      1  2022         CB radios are free from govt/media control
# 1   27      1  2022                      And in the darkness bind them
# 2   27      1  2022  Honestly, I would let the border regions vote....
# 3   27      1  2022                                      Vote them out
# 4   27      1  2022  If you scare people enough, they will demand r...
#
#    Retweets   Likes
# 0     11302  113429
# 1     33028  195919
# 2       281    4627
# 3      7712   68748
# 4    119804  543466

# %%
import re

# %%
df['Cleaned_Tweets'] = df['Cleaned_Tweets'].str.replace('[^\w\s#@/:%.,_-]', '', regex=True, flags=re.UNICODE)

# %%
df
# Out:
#       day  month  year                                     Cleaned_Tweets  \
# 0      27      1  2022         CB radios are free from govt/media control
# 1      27      1  2022                      And in the darkness bind them
# 2      27      1  2022  Honestly, I would let the border regions vote....
# 3      27      1  2022                                      Vote them out
# 4      27      1  2022  If you scare people enough, they will demand r...
# ...   ...    ...   ...                                                ...
# 2663   26     10  2022                                         Concerning
# 2664   26     10  2022  âAccording to unnamed sources close to the mat...
# 2665   27     10  2022                           Dear Twitter Advertisers
# 2666   27     10  2022                                         Absolutely
# 2667   27     10  2022                                             thanks
#
#       Retweets   Likes
# 0        11302  113429
# 1        33028  195919
# 2          281    4627
# 3         7712   68748
# 4       119804  543466
# ...        ...     ...
# 2663       719   17443
# 2664      4603   62693
# 2665     55927  356623
# 2666       755   26737
# 2667       209    7021
#
# [2668 rows x 6 columns]

# %%
df.to_csv("./data/elon_tweets.csv")

# %% [markdown]
# ### Export to SQL using sqlalchemy

# %%
import sqlalchemy as alch
import os
from dotenv import load_dotenv

load_dotenv()

# Establishing connection
password = os.getenv('sqlpassword')
dbName = "tweets"
connectionData = f"mysql+pymysql://root:{password}@127.0.0.1/{dbName}"
engine = alch.create_engine(connectionData)
